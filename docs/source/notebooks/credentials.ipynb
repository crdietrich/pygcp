# %% [markdown]
# # Credentials
# To use services on Google Cloud Platform, authentication is needed to assign incurred costs and grant access to specific services and data sources. As previously set in the `config.ipynb` Notebook, we'll use the values in those Jupyter shared variables to create credential class instances that will allow us to use GCP services wherever our code is run.

# %%
# %store -r cred_file

# %%
from pygcp import credentials

# %%
gcp_credentials = credentials.create_credentials(cred_file)

# %%
type(gcp_credentials)
# Out:
# google.oauth2.service_account.Credentials

# %%
gcp_credentials.scopes
# Out:
# ['https://www.googleapis.com/auth/cloud-platform',
#  'https://www.googleapis.com/auth/drive',
#  'https://www.googleapis.com/auth/spreadsheets']

# %%
gcp_credentials.project_id
# Out:
# 'sada-colin-dietrich'

# %% [markdown]
# In other Notebooks we'll use `gcp_credentials` to initialize API sessions to GCP services.
